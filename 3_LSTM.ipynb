# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import libraries
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from keras.preprocessing import sequence
np.random.seed(7)
# Out:
# WARNING:tensorflow:From C:\Users\juvvi\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
top_words = 5000
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=top_words)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 8s 0us/step

# %%
print('Shape of training data: ')
print(X_train.shape)
print(y_train.shape)
print('Shape of test data: ')
print(X_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (25000,)
# (25000,)
# Shape of test data:
# (25000,)
# (25000,)

# %%
# truncate and pad input sequences
max_review_length = 500
X_train = sequence.pad_sequences(X_train, maxlen=max_review_length)
X_test = sequence.pad_sequences(X_test, maxlen=max_review_length)

# %%
# create the model
epochs = 10

embedding_vecor_length = 16
model = Sequential()
model.add(Embedding(top_words, embedding_vecor_length, input_length=max_review_length))
model.add(LSTM(16))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\juvvi\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\juvvi\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 16)           80000
#
#  lstm (LSTM)                 (None, 16)                2112
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 82129 (320.82 KB)
# Trainable params: 82129 (320.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=64)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\juvvi\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\juvvi\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 391/391 [==============================] - 67s 163ms/step - loss: 0.5118 - accuracy: 0.7477 - val_loss: 0.3416 - val_accuracy: 0.8560
# Epoch 2/10
# 391/391 [==============================] - 59s 150ms/step - loss: 0.3064 - accuracy: 0.8778 - val_loss: 0.3287 - val_accuracy: 0.8617
# Epoch 3/10
# 391/391 [==============================] - 59s 152ms/step - loss: 0.2591 - accuracy: 0.8993 - val_loss: 0.3005 - val_accuracy: 0.8739
# Epoch 4/10
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2335 - accuracy: 0.9095 - val_loss: 0.3099 - val_accuracy: 0.8700
# Epoch 5/10
# 391/391 [==============================] - 63s 161ms/step - loss: 0.2169 - accuracy: 0.9184 - val_loss: 0.2966 - val_accuracy: 0.8846
# Epoch 6/10
# 391/391 [==============================] - 68s 173ms/step - loss: 0.2069 - accuracy: 0.9238 - val_loss: 0.3817 - val_accuracy: 0.8712
# Epoch 7/10
# 391/391 [==============================] - 71s 182ms/step - loss: 0.1952 - accuracy: 0.9291 - val_loss: 0.2950 - val_accuracy: 0.8816
# Epoch 8/10
# 391/391 [==============================] - 74s 188ms/step - loss: 0.1864 - accuracy: 0.9326 - val_loss: 0.3114 - val_accuracy: 0.8786
# Epoch 9/10
# 391/391 [==============================] - 73s 186ms/step - loss: 0.1802 - accuracy: 0.9336 - val_loss: 0.3099 - val_accuracy: 0.8809
# Epoch 10/10
# 391/391 [==============================] - 75s 191ms/step - loss: 0.1736 - accuracy: 0.9361 - val_loss: 0.3280 - val_accuracy: 0.8703

# %%
#evaluate the model
test =  model.evaluate(X_test, y_test, verbose=0)
print("Testing Accuracy: %.2f%%" % (test[1]*100))
# Out:
# Testing Accuracy: 87.03%

# %%
def plot_result(history, epoch):

    epoch_range = range(1, epoch+1)

    plt.plot(epoch_range, history.history['accuracy'], label='Training acc')
    plt.plot(epoch_range, history.history['val_accuracy'], label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('epochs')
    plt.ylabel('acc')
    plt.legend(loc='upper left')
    plt.savefig('acc.jpg')

    plt.show()

    plt.plot(epoch_range, history.history['loss'], label='Training loss')
    plt.plot(epoch_range, history.history['val_loss'], label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend(loc='upper left')
    plt.savefig('loss.jpg')

    plt.show()

# %%
plot_result(history, epochs)
